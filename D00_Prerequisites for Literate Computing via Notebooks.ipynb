# %% [markdown]
# # About: Prerequisites for Literate Computing via Notebooks
# 文芸的機械化の準備 - Notebookでね
#
# ----
#
# This notebook describes enviromental prerequisits in order to utilize the set of notebooks under this directory.
# Prerequisits cover both for the originate host where notebooks operate and for the target hosts manipulated by notebooks.
#
# ここでは本ディレクトリに含まれるNotebookを利用するために必要となる環境条件を明示的に定義している。
# 環境条件には、Notebookを動作させているホストマシンの環境、およびNotebookで操作しようとしている対象ホスト群の環境が含まれる。
#
# ----
#
# 自身のNotebook環境にNotebookをコピーした後、読み進めることで条件を満たしているか確認できる。
#
# 条件には推奨の度合いによりレベルがあり、 **A=必須、B=推奨、C=任意** というレベルを設定してある。
#
# このNotebookを確認することで、Notebookで操作しようとしている捜査対象ホスト群が **Seedingが済んだ状態である** ことを確認できる。

# %% [markdown]
# # Ansibleの設定
#
# Notebook環境は、以下の条件を満たしている必要がある。
#
# ## Ansibleがインストールされていること - A
#
# 以下のコマンド実行がエラーとならず、インストールされているAnsibleのバージョンが表示されること。

# %%
# !ansible --version
# Out:
# ansible XXX.XXX.XXX.0
#   config file = /etc/ansible/ansible.cfg
#   configured module search path = Default w/o overrides

# %% [markdown]
# ansibleコマンドがインストールされていない場合は、[Installing the Control Machine](http://docs.ansible.com/ansible/intro_installation.html#installing-the-control-machine)を参考に、Ansibleをインストールする。

# %% [markdown]
# ## AnsibleでDefault Moduleが利用可能であること - A
#
# DefaultのModuleが使えればよい。特にカスタマイズすべき項目はなし。*...将来は腐っているモジュールは差し替えたい。*

# %% [markdown]
# # Ansible - Binding対象間の設定
#
# このNotebook環境にインストールされているAnsibleは、Binding対象となるホストに対して通信、操作可能な状態になっている必要がある。

# %% [markdown]
# ## Default Inventoryが設定されていること - B
#
# 以下のコマンド実行がエラーとならず、 `inventory = (Default Inventoryのパス)` が設定されていること。
#
# > これを指定しないと、運用Notebookのansible実行ごとにInventoryを指定する必要がある・・・あまりNotebookには **Notebookが動作する環境に依存した項目を書きたくない** ので必須としている。

# %%
# !cat ${ANSIBLE_CONFIG:-/etc/ansible/ansible.cfg} | grep --color=always -A 2 -B 2 "^inventory"
# Out:
# allow_world_readable_tmpfiles = True
#
# inventory = /notebooks/inventory

# %% [markdown]
# [Configuration file](http://docs.ansible.com/ansible/intro_configuration.html) を参考にしながら、Default Inventoryを指定しておく。Default Inventoryを指定しない場合は、対象とのBindingの際にInventoryの指定を加えること。

# %% [markdown]
# ## Inventoryに指定されたホストに到達可能なこと - A
#
# AnsibleのInventoryに指定された全ホストに対して、この環境からアクセス可能であること。
#
# - 以下のコマンド実行がエラーもしくは警告(`provided hosts list is empty`)とならないこと
# - Inventoryに登録されているホストに関して、すべてSUCCESSとなること

# %%
# !ansible -m ping all
# Out:
# XXX.XXX.XXX.193 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.194 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.229 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.197 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.198 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.196 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.195 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.199 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.70 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.71 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.72 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.200 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.106 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.230 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.228 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.226 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.225 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.236 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.234 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.232 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.231 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.227 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.233 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.235 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.73 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.112 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.114 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.113 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }

# %% [markdown]
# このNotebook環境のAnsibleから、ホストへの認証方法については特に問わない。
#
# > 我々(NIIクラウド運用チーム)の環境ではkeypairによる認証を使ってAnsibleから各ホストにアクセスをしている。
# > そのため、以下のpublic keyをBinding対象ホストの `~/.ssh/authorized_keys` に設定している。

# %%
# !cat ~/.ssh/id_rsa.pub
# Out:
# ssh-rsa  ansible@XXXXXXXXXXXX

# %% [markdown]
# ## 適切なユーザで認証されること - B
#
# Ansibleからホストへの認証は、一般ユーザとして認証されるようにしておく。
#
# > 我々(NIIクラウド運用チーム)の環境では、ユーザ ansible を作って対応している。

# %%
# !ansible -a 'whoami' all
# Out:
# XXX.XXX.XXX.194 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.193 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.229 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.197 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.196 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.195 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.198 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.199 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.70 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.72 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.71 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.106 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.200 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.230 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.228 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.226 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.225 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.236 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.234 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.232 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.231 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.233 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.227 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.235 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.73 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.112 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.113 | SUCCESS | rc=0 >>
# ansible
#
# XXX.XXX.XXX.114 | SUCCESS | rc=0 >>
# ansible

# %% [markdown]
# ## Binding対象ホストにてsudo可能であること - A
#
# Inventoryに記述された全ホストに関してbecome, become-userが可能であることを確認しておく。
#
# - 以下のコマンド実行がエラーとならないこと
# - Inventoryに登録されているホストに関して、すべてSUCCESSとなり、結果がrootとなること

# %%
# !ansible --become --become-user root -a 'whoami' all
# Out:
# XXX.XXX.XXX.194 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.193 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.229 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.197 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.196 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.195 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.198 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.199 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.70 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.71 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.72 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.106 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.200 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.226 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.225 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.236 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.230 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.228 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.234 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.232 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.231 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.227 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.233 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.235 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.73 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.112 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.113 | SUCCESS | rc=0 >>
# root
#
# XXX.XXX.XXX.114 | SUCCESS | rc=0 >>
# root

# %% [markdown]
# 以上の項目が満たされていればOK。

# %% [markdown]
# # Notebookから利用するツールの設定
#
# Ansible以外に、Notebookからツールの呼び出しをおこなう場合がある。

# %% [markdown]
# ## zk-shellがインストールされていること - A
#
# ZooKeeperをインストールしたのち動作確認をNotebookからおこなうため、 [zk-shell](https://github.com/rgs1/zk_shell) をインストールしておく。

# %%
# !which zk-shell
# Out:
# /usr/local/bin/zk-shell

# %% [markdown]
# `zk-shell` コマンドがこの環境にインストールされていない場合は、以下のようにpipコマンドなどでインストールをおこなっておく。

# %%
#!pip install zk-shell

# %% [markdown]
# 以上の項目が満たされていればOK。

# %% [markdown]
# # Binding対象の設定
#
# Binding対象に関して、Notebook + Ansibleによる管理を適用する上で適切な設定になっていることを確認する。

# %% [markdown]
# ## Ansibleによる操作ログが記録されていること - B
#
# NotebookからBinding対象の操作をおこなった際に、過去おこなった操作を適切に参照できる必要がある。
#
# > 我々の環境では、ansibleによる操作は `/var/log/secure` (CentOSの場合) `/var/log/auth.log` (Ubuntuの場合) に記録されている

# %%
# !ansible -b -m shell -a 'grep ansible- /var/log/* | tail' all
# Out:
# XXX.XXX.XXX.194 | SUCCESS | rc=0 >>
# /var/log/secure-20160814:Aug  9 14:01:36 cn01070602 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ijncbcuunzlpsmhyyngixhsnmfwzpxdi; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718896.51-239261932769290/command
# /var/log/secure-20160814:Aug  9 14:02:09 cn01070602 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-viciijranotuqsonxtzfwthjqqyiegec; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718929.36-104566809609135/command
# /var/log/secure-20160814:Aug  9 14:02:12 cn01070602 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-jqnkoapejwdfxsprokdkdiooctcxrvtp; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718932.69-215855992171109/command
# /var/log/secure-20160814:Aug  9 15:06:30 cn01070602 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-zlnbogvqehegraukinhazqdrcexmsgxr; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722790.71-113298604275350/command
# /var/log/secure-20160814:Aug  9 15:06:34 cn01070602 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-fwzomsftjwwohxodvjnloszcuhmyxbdv; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722794.11-204889461783836/command
# /var/log/secure-20160814:Aug  9 15:08:55 cn01070602 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-skzroessxonabyododwpyyxuxcvnewcp; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722935.13-36076434858906/command
# /var/log/secure-20160814:Aug  9 15:08:58 cn01070602 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-svpbgazqifebwvdlkvjfvjsdksotgelb; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722938.59-42937297198649/command
# /var/log/secure-20160821:Aug 19 11:48:49 cn01070602 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-bbcoxwpgutlobvbzxwbkrbagemydmdri; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574928.98-79016365725193/command
# /var/log/secure-20160821:Aug 19 11:49:24 cn01070602 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-kpndrgtmxrulykgjbnaaflostakewdqr; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574964.43-161620451843825/command
# /var/log/secure-20160821:Aug 19 11:49:47 cn01070602 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-gedfeakrzgmscnjkjojemxwfkctaawzg; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574987.23-54077849947931/commandgrep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/hive: Is a directory
# grep: /var/log/hive-hcatalog: Is a directory
# grep: /var/log/httpd: Is a directory
# grep: /var/log/lost+found: Is a directory
# grep: /var/log/munin: Is a directory
# grep: /var/log/munin-node: Is a directory
# grep: /var/log/resources: Is a directory
# grep: /var/log/sa: Is a directory
# grep: /var/log/spark: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.229 | SUCCESS | rc=0 >>
# /var/log/secure-20160731:Jul 28 16:40:22 sn02020801 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ambyslsmymhntksoywvyutxoxqdfkery; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469691622.81-11015102441315/service; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469691622.81-11015102441315/" > /dev/null 2>&1
# /var/log/secure-20160731:Jul 28 16:40:52 sn02020801 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-bhhqmagmyqdlfealiurcaqmrfudwyquo; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469691652.03-197780663544531/setup; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469691652.03-197780663544531/" > /dev/null 2>&1
# /var/log/secure-20160731:Jul 28 16:40:53 sn02020801 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-htwpgrwxiqbfxruegwsxecbeloniweeq; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469691653.61-160989406709157/service; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469691653.61-160989406709157/" > /dev/null 2>&1
# /var/log/secure-20160731:Jul 28 16:45:05 sn02020801 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-excjyampxvqvrofxnuttgmgsslmfnzsq; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469691905.37-19253084653091/setup; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469691905.37-19253084653091/" > /dev/null 2>&1
# /var/log/secure-20160731:Jul 28 16:45:10 sn02020801 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-owctwhwxyfybakrqdljtjcknyritnlcx; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469691910.46-7378460793134/service; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469691910.46-7378460793134/" > /dev/null 2>&1
# /var/log/secure-20160731:Jul 28 16:45:35 sn02020801 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-emwmzdgdmrzzgdsbtpfivycfnpesjzhh; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469691934.96-99452882538261/setup; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469691934.96-99452882538261/" > /dev/null 2>&1
# /var/log/secure-20160731:Jul 28 16:45:36 sn02020801 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ettlozickpqqdqoxiozhrboqamozwezr; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469691936.78-277119961115255/service; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469691936.78-277119961115255/" > /dev/null 2>&1
# /var/log/secure-20160731:Jul 28 16:45:59 sn02020801 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-afyjlufzbxoaypeavropozpcfronvntn; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469691959.24-133112967331207/setup; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469691959.24-133112967331207/" > /dev/null 2>&1
# /var/log/secure-20160731:Jul 28 16:46:00 sn02020801 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-nefcwnsvfilrcxyepioezqfcbmtdcohh; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469691960.83-191800585832401/service; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469691960.83-191800585832401/" > /dev/null 2>&1
# /var/log/secure-20160731:Jul 28 16:55:24 sn02020801 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-jmtxbyjckottwhfqmotplpcuuwsrmfyg; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469692524.12-191394472491486/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469692524.12-191394472491486/" > /dev/null 2>&1grep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-mapreduce: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/lost+found: Is a directory
# grep: /var/log/munin: Is a directory
# grep: /var/log/munin-node: Is a directory
# grep: /var/log/resources: Is a directory
# grep: /var/log/sa: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.193 | SUCCESS | rc=0 >>
# /var/log/secure-20160814:Aug  9 14:01:36 cn01070601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-yyftnpcptsmxoulwqnxgqmxsfcbnodat; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718896.16-191070118882770/command
# /var/log/secure-20160814:Aug  9 14:02:09 cn01070601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-nzprwuzvrphoknhpkjqsefvgftuueidd; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718929.36-207924328963518/command
# /var/log/secure-20160814:Aug  9 14:02:12 cn01070601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-rathmguaeixuqdaepuambtbiddxpbbmb; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718932.69-278187735507901/command
# /var/log/secure-20160814:Aug  9 15:06:30 cn01070601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-wbjqfgrfyaxdlhpftttfwwibmyyfjcti; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722790.71-108323349829713/command
# /var/log/secure-20160814:Aug  9 15:06:34 cn01070601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-uvfpskfmtxwmzdkfrurffomvsgtltvvy; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722794.11-98921682496033/command
# /var/log/secure-20160814:Aug  9 15:08:55 cn01070601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-laurrbacwlwkpviqgazedhvraysndoan; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722935.13-79315694569295/command
# /var/log/secure-20160814:Aug  9 15:08:58 cn01070601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ettrxxylagmqdojrvqabszqiyuqjoggt; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722938.59-59632425297535/command
# /var/log/secure-20160821:Aug 19 11:48:47 cn01070601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-xmetzkvrxtztnnzbheuuokbjcuqznzde; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574927.06-23048575070478/command
# /var/log/secure-20160821:Aug 19 11:49:22 cn01070601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-casxuaxqutiazqtcuygykbckrcrbzxqt; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574962.6-141310770146805/command
# /var/log/secure-20160821:Aug 19 11:49:45 cn01070601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-npjgtccuydwdrusjgajiuyssbirnrxar; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574985.4-184249576955339/commandgrep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/httpd: Is a directory
# grep: /var/log/lost+found: Is a directory
# grep: /var/log/munin: Is a directory
# grep: /var/log/munin-node: Is a directory
# grep: /var/log/resources: Is a directory
# grep: /var/log/sa: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.197 | SUCCESS | rc=0 >>
# /var/log/secure-20160814:Aug  9 14:02:02 cn01070401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-qywitjbkfbbijqjvkagedtyseezgheuh; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718922.74-277679789707761/command
# /var/log/secure-20160814:Aug  9 14:02:06 cn01070401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-mlkzdvczzlujphqtpyynjdcasucctcvm; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718926.12-220664716149253/command
# /var/log/secure-20160814:Aug  9 14:27:31 cn01070401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-trdbsirqcaudvttisyahaikhqezlgmig; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470720451.65-59323072644963/setup; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470720451.65-59323072644963/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  9 15:06:23 cn01070401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ezjmmfrainkecqsfgchviofgnicccwjs; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722782.95-209618656190202/command
# /var/log/secure-20160814:Aug  9 15:06:27 cn01070401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-xpnzvmssnvbkqruwuekbqqdfjjntlksv; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722787.39-214716098231653/command
# /var/log/secure-20160814:Aug  9 15:08:47 cn01070401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-tjjkwcwxeqmwlbfwsertotyooroezfgd; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722927.25-176108966564409/command
# /var/log/secure-20160814:Aug  9 15:08:51 cn01070401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-kimqqldzjkcshxxzknsqqfmokbamfnis; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722931.78-207396301620476/command
# /var/log/secure-20160821:Aug 19 11:48:47 cn01070401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-lsgunzfcpuvnnccnxeakksdaupblyirn; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574927.06-209936486844887/command
# /var/log/secure-20160821:Aug 19 11:49:22 cn01070401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-xpikehbgnwtloqwdkvzqubegaohvgfdc; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574962.6-22578902322713/command
# /var/log/secure-20160821:Aug 19 11:49:45 cn01070401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-tbmembzdmhhfknkwvereabipxzlbfoyb; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574985.4-260145818654697/commandgrep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/lost+found: Is a directory
# grep: /var/log/munin: Is a directory
# grep: /var/log/munin-node: Is a directory
# grep: /var/log/resources: Is a directory
# grep: /var/log/sa: Is a directory
# grep: /var/log/td-agent: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.196 | SUCCESS | rc=0 >>
# /var/log/secure-20160731:Jul 29 12:36:14 cn01070604 sudo: ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ximrybwczffzpmjpbvwehnbopyunazjg; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469763374.22-29532509281144/slurp; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469763374.22-29532509281144/" > /dev/null 2>&1
# /var/log/secure-20160731:Jul 29 13:09:07 cn01070604 sudo: ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-vtrxxlrxmisincyehbqnnjaztxuavpqa; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1469765347.5-258487155488717/slurp; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1469765347.5-258487155488717/" > /dev/null 2>&1
# /var/log/secure-20160808:Aug  2 10:26:56 cn01070604 sudo: ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-wssibiafcqamynwaupkltkpglnxopxsw; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470101216.06-248228400334312/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470101216.06-248228400334312/" > /dev/null 2>&1
# /var/log/secure-20160808:Aug  2 10:27:31 cn01070604 sudo: ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-jiztyiqfhtduhntdbotnydchxrdutcmx; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470101250.92-39983860146034/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470101250.92-39983860146034/" > /dev/null 2>&1
# /var/log/secure-20160808:Aug  2 10:29:19 cn01070604 sudo: ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-mbtojhrbumpiapwpocbozsobuzfxcwqf; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470101358.54-206600554321902/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470101358.54-206600554321902/" > /dev/null 2>&1
# /var/log/secure-20160808:Aug  2 10:30:26 cn01070604 sudo: ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-nzdzvyqtloodbadchsiccfhoypisqgdj; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470101426.27-8591708801234/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470101426.27-8591708801234/" > /dev/null 2>&1
# /var/log/secure-20160808:Aug  2 10:30:35 cn01070604 sudo: ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-raxrinijsoixzwqcevevsbpcoigkbbbo; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470101435.55-167329451375945/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470101435.55-167329451375945/" > /dev/null 2>&1
# /var/log/secure-20160808:Aug  2 10:30:53 cn01070604 sudo: ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-scwaaoramqeahtdkzqzfpegudlgyhbxx; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470101453.13-172933680007493/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470101453.13-172933680007493/" > /dev/null 2>&1
# /var/log/secure-20160808:Aug  2 10:31:01 cn01070604 sudo: ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-suiftnybvhtqluijigxprewauuvvhubl; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470101461.51-72595480796990/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470101461.51-72595480796990/" > /dev/null 2>&1
# /var/log/secure-20160808:Aug  2 10:31:57 cn01070604 sudo: ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-zljcftdzetstudffcwxqqagndrfywtgq; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470101517.52-84587622900124/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470101517.52-84587622900124/" > /dev/null 2>&1grep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-mapreduce: Is a directory
# grep: /var/log/hive: Is a directory
# grep: /var/log/hive-hcatalog: Is a directory
# grep: /var/log/httpd: Is a directory
# grep: /var/log/lost+found: Is a directory
# grep: /var/log/munin: Is a directory
# grep: /var/log/munin-node: Is a directory
# grep: /var/log/resources: Is a directory
# grep: /var/log/sa: Is a directory
# grep: /var/log/spark: Is a directory
# grep: /var/log/td-agent: Is a directory
# grep: /var/log/tuned: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.198 | SUCCESS | rc=0 >>
# /var/log/secure-20160814:Aug  9 14:02:02 cn01070402 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-pahkzdfancgcnchozmtbiazjhgdaxgfh; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718922.74-105067164492210/command
# /var/log/secure-20160814:Aug  9 14:02:06 cn01070402 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-qjtxdppbokxnwgoricsqfateymlxkbde; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718926.12-265998565929270/command
# /var/log/secure-20160814:Aug  9 14:27:31 cn01070402 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-hksebijlbborgbfgvnlmcwyapvfvchxq; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470720451.65-83316846398870/setup; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470720451.65-83316846398870/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  9 15:06:23 cn01070402 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-rjtasgcvycyjvamwokcqbsbxcjsdijiw; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722782.95-158087692459077/command
# /var/log/secure-20160814:Aug  9 15:06:27 cn01070402 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-trcvppewxhfxlaljzjrfrxdrseclpuke; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722787.39-225130547377123/command
# /var/log/secure-20160814:Aug  9 15:08:47 cn01070402 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-cwruermvwphiejibneewjuwuvkvgwxyz; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722927.25-47876455761723/command
# /var/log/secure-20160814:Aug  9 15:08:51 cn01070402 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-idrtsefvcsbtjryewcrzwigpsxsuvhyy; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470722931.78-229987907490481/command
# /var/log/secure-20160821:Aug 19 11:48:47 cn01070402 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-exfesucknupsmepndtrbaqzcnftrdlpp; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574927.06-58893847813552/command
# /var/log/secure-20160821:Aug 19 11:49:22 cn01070402 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-rwwplpovjeayuxtmmhvfvqvgdwgqumea; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574962.6-269515488202223/command
# /var/log/secure-20160821:Aug 19 11:49:45 cn01070402 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-wfbvrefevhmybgqxphcomnqucitdxeae; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574985.4-172765801347106/commandgrep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/lost+found: Is a directory
# grep: /var/log/munin: Is a directory
# grep: /var/log/munin-node: Is a directory
# grep: /var/log/resources: Is a directory
# grep: /var/log/sa: Is a directory
# grep: /var/log/td-agent: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.199 | SUCCESS | rc=0 >>
# /var/log/secure-20160814:Aug  8 14:29:56 cn01070403 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-zmfdjendcgzpfqswgripuxcohuhpkvas; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634196.01-250621604201714/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634196.01-250621604201714/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:29:59 cn01070403 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-unnszrddvnemuvknntldapekbfzaqhzh; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634199.03-237959480530036/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634199.03-237959480530036/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:01 cn01070403 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-xtidgmtdjydtatvpgcbhkjhiztljrmvk; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634201.78-276936573191757/file; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634201.78-276936573191757/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:05 cn01070403 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-itsrbkjgrotrayqlrbmmwobytovlmylm; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634205.64-132596983874887/stat; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634205.64-132596983874887/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:09 cn01070403 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-nsikgiscjsidgzzaxqsmulobfkzxqpna; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634208.96-147311628080019/file; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634208.96-147311628080019/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:13 cn01070403 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-xtlqjnffoxxkwaylwoojbeewaewxotof; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634212.97-225145725447304/stat; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634212.97-225145725447304/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:16 cn01070403 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-fsbhoqdvizebrzfcujfabgujaaihlcwh; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634216.44-154475216008771/file; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634216.44-154475216008771/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:20 cn01070403 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-dofhhiapchjprusforvudvcqqrbmkohx; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634220.65-241548314671494/stat; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634220.65-241548314671494/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:24 cn01070403 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-gqaknbfmmmnthynnjqudcuyfxuzkiiuq; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634224.1-185650853032672/file; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634224.1-185650853032672/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  9 14:27:31 cn01070403 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-uzrgonqdqxodnrlhqnnqyxdiunyxthlb; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470720451.65-29576363759043/setup; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470720451.65-29576363759043/" > /dev/null 2>&1grep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-mapreduce: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hive-hcatalog: Is a directory
# grep: /var/log/httpd: Is a directory
# grep: /var/log/lost+found: Is a directory
# grep: /var/log/munin: Is a directory
# grep: /var/log/munin-node: Is a directory
# grep: /var/log/resources: Is a directory
# grep: /var/log/sa: Is a directory
# grep: /var/log/spark: Is a directory
# grep: /var/log/td-agent: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.70 | SUCCESS | rc=0 >>
# /var/log/secure-20160821:Aug 19 11:48:49 testvm001 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-huazpowupfahinzzmowqtlemuxfgetgt; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574929.0-21901640188031/command
# /var/log/secure-20160821:Aug 19 11:48:54 testvm001 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-nrjdlttnpwnfzofgxxgnipgsbuzxcilo; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574934.34-5073601064728/command
# /var/log/secure-20160821:Aug 19 11:49:25 testvm001 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-hxwsxnxnhbonsgcplzihkcvxlugzstdg; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574965.38-188123087039689/command
# /var/log/secure-20160821:Aug 19 11:49:47 testvm001 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ybzfrtncfowfzocuaqcothlhhfpjoagv; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574987.24-234260850651027/command
# /var/log/secure-20160821:Aug 19 11:51:08 testvm001 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-dtgiizgzgynbvzilcoesxbcgdcopvgvs; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575068.11-147864293394157/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575068.11-147864293394157/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:54:18 testvm001 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-raficfjoiytpprtpivxbniapwytaebeq; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575258.28-277490834361238/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575258.28-277490834361238/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:55:32 testvm001 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-nkmoahgsanuwfgzhzimnhmjltxuiayxb; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575332.46-214484798015634/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575332.46-214484798015634/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:13 testvm001 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-bqgwjinfmygkezordbgphnklysaqppbi; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575373.83-73030864564455/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575373.83-73030864564455/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:52 testvm001 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-syrtxesutidasvggbxojdenkvbujebtu; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575412.53-256819537672122/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575412.53-256819537672122/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:57:54 testvm001 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-nbttfxkaoaxerftzwovkvnochhszlvgk; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575474.1-24343536819221/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575474.1-24343536819221/" > /dev/null 2>&1grep: /var/log/audit: Is a directory
# grep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/ntpstats: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.71 | SUCCESS | rc=0 >>
# /var/log/secure-20160821:Aug 19 11:48:32 testvm002 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-rbhfcqeduzxpwdtyswrifoubsemaofbm; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574912.1-119066299894754/command
# /var/log/secure-20160821:Aug 19 11:48:50 testvm002 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-qwipvpmoxpbydbqenqklrtwexdulwtkq; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574929.93-14179174572029/command
# /var/log/secure-20160821:Aug 19 11:49:25 testvm002 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-sdznrqyeujxdmgxjjczjsgfmmagbggir; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574965.42-166047435435707/command
# /var/log/secure-20160821:Aug 19 11:49:48 testvm002 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-kaseqkrdriazediqfyfzinbfkhijkaha; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471574988.17-8394931137775/command
# /var/log/secure-20160821:Aug 19 11:51:08 testvm002 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-zhnbhdefebjkmwkoaxjjliczafjegqhb; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575068.11-15250394495510/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575068.11-15250394495510/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:54:18 testvm002 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-jpjpynlgnjzisopvsnayonwmeofwcbyb; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575258.28-59862539208206/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575258.28-59862539208206/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:55:32 testvm002 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ulwoomvkfglpuffuffpqyqknaowmnkwu; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575332.46-256833045353446/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575332.46-256833045353446/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:13 testvm002 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-qvkkjaausaqlnhdhhkdhqgawtgunzvbv; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575373.83-128733926196276/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575373.83-128733926196276/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:52 testvm002 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-zqxgzmanfeynwwmxfohlqmapowbfcjsj; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575412.53-36540835089487/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575412.53-36540835089487/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:57:54 testvm002 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-oiilynddjlmcbndekycfszsxkjuwfmul; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575474.1-21471092179400/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575474.1-21471092179400/" > /dev/null 2>&1grep: /var/log/audit: Is a directory
# grep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/ntpstats: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.72 | SUCCESS | rc=0 >>
# /var/log/secure-20160821:Aug 19 11:47:12 testvm003 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-lqpbiutyghcpdfqlfkaxwnmzrkilzdao; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471574832.7-241926509523530/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471574832.7-241926509523530/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:49:07 testvm003 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-xzlteufltzfkwtqcaoklzgizvqnprnui; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471574947.69-184298961493674/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471574947.69-184298961493674/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:54:18 testvm003 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ihmhjwhegeqzitcrkdrbapfhambawzqo; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575258.28-243258042406254/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575258.28-243258042406254/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:55:32 testvm003 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-lbagbabgggayeaxfdryfkxdhsymglhox; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575332.46-85258425149182/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575332.46-85258425149182/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:13 testvm003 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-odetxwbgzvcuoydcaqfqyavglsixojjg; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575373.83-146402255866948/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575373.83-146402255866948/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:52 testvm003 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-aquniheveyblbrdmuolgrnoohgvvyher; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575412.53-170786758819538/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575412.53-170786758819538/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:57:54 testvm003 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-zmbijkmqbcjtmjnqsnzdzmrjeagxpvpt; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575474.1-205166906491562/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575474.1-205166906491562/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 12:03:43 testvm003 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-emhczftqgjchqqkaujcdqhjfolfveqvj; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575823.52-52010677492385/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575823.52-52010677492385/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 12:03:55 testvm003 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-nyfrwpdwplwhbmhacdranfqpfmzkdypw; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575835.03-144131592512324/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575835.03-144131592512324/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 12:11:53 testvm003 sudo:  ansible : TTY=pts/1 ; PWD=/home/ansible ; USER=spark ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-cvgybyykmqiguodfhfzopcjqkrzkclju; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1471576312.97-24029088378080/commandgrep: /var/log/audit: Is a directory
# grep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-mapreduce: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hive: Is a directory
# grep: /var/log/hive-hcatalog: Is a directory
# grep: /var/log/ntpstats: Is a directory
# grep: /var/log/spark: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.200 | SUCCESS | rc=0 >>
# /var/log/secure-20160814:Aug  8 14:36:05 cn01070404 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ygpzqdudkuvrqenrkxwwmgvncoqzjxhy; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470634564.85-141789157697027/command
# /var/log/secure-20160814:Aug  8 14:36:06 cn01070404 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-mindzgihzvnokflwyaegcaajgbudutmm; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470634566.65-91246549360633/command
# /var/log/secure-20160814:Aug  8 14:36:20 cn01070404 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-fgdkzxkzgufgxyyevlqwiukrrstrfgqj; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470634580.35-161381584190515/command
# /var/log/secure-20160814:Aug  9 14:01:30 cn01070404 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-igkypimtgqghedikidhaeamvrvzwdasx; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718890.17-245386719211448/command
# /var/log/secure-20160814:Aug  9 14:01:32 cn01070404 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-xbcobttkimatpainyqtxbntarqcqubay; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470718891.93-224060969639203/command
# /var/log/secure-20160814:Aug  9 14:23:15 cn01070404 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-cgpyvfnnjcqwcaugpatqwatnrlusyxgy; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470720195.26-46580011456622/command
# /var/log/secure-20160814:Aug  9 14:27:32 cn01070404 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-kegrfxjgpvgumfycftpjxshntyzcxngd; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470720452.39-99667460087505/setup; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470720452.39-99667460087505/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  9 14:28:31 cn01070404 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-pvbqqqyujasnltirowzixivtpfitmtgy; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470720511.79-91875706285030/command
# /var/log/secure-20160814:Aug  9 14:28:48 cn01070404 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=hdfs ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-hjqmltttivystkyfzodxzoktctdbfagy; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470720528.75-256171316394698/command
# /var/log/secure-20160814:Aug  9 14:29:15 cn01070404 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=yarn ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-gxhskwriiaogtfpmcnyoniptmvzjnpzq; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /tmp/ansible-tmp-1470720555.76-248093934671221/commandgrep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-mapreduce: Is a directory
# grep: /var/log/hive: Is a directory
# grep: /var/log/hive-hcatalog: Is a directory
# grep: /var/log/httpd: Is a directory
# grep: /var/log/lost+found: Is a directory
# grep: /var/log/munin: Is a directory
# grep: /var/log/munin-node: Is a directory
# grep: /var/log/resources: Is a directory
# grep: /var/log/sa: Is a directory
# grep: /var/log/spark: Is a directory
# grep: /var/log/td-agent: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.106 | SUCCESS | rc=0 >>
# /var/log/secure-20160821:Aug 18 19:20:57 cn04061401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-xssminskaemxsrbuqptwsultnatjbzyf; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471515657.81-273071976293880/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471515657.81-273071976293880/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 18 19:20:59 cn04061401 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-alrhoaqcodwuohqtyyyrgfdsojamdrtt; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471515659.31-45889618655542/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471515659.31-45889618655542/" > /dev/null 2>&1
# ...
# /var/log/secure-20160821:Aug 19 11:56:14 testvm005 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-slppuvwpbomkfeeqpztckmvyjzrubrng; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575374.11-99787892828133/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575374.11-99787892828133/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:52 testvm005 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-xshpfdpwghxfvdtszzswruhrpdlcixvh; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575412.8-113655712407208/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575412.8-113655712407208/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:57:54 testvm005 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-sdjwgizgrenbascezgvwrvhjykivxxci; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575474.49-209087343146862/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575474.49-209087343146862/" > /dev/null 2>&1grep: /var/log/audit: Is a directory
# grep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/ntpstats: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.233 | SUCCESS | rc=0 >>
# /var/log/secure-20160814:Aug  8 14:29:54 sn02031601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-smfxvajbuudtmmqttzqqofwmywmggcvn; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634193.93-197512568289704/file; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634193.93-197512568289704/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:29:57 sn02031601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ripvuyybghoubjlzyzehnopuhdguepey; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634197.82-17997184136576/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634197.82-17997184136576/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:00 sn02031601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-eeonythjchhqtcdxxtsoammkrxdngzqi; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634200.58-178816556750764/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634200.58-178816556750764/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:03 sn02031601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ooqjkljkckdshzzwlvgaszvlxhiluvyx; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634203.39-36860934503579/file; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634203.39-36860934503579/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:07 sn02031601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-mntnvmgqiuaxatrdgaigenljbvyxjdxc; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634207.24-101930947729701/stat; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634207.24-101930947729701/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:10 sn02031601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ruhqmeausvliqgtfyuoebbaxpfvrsfwc; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634210.52-207275935040320/file; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634210.52-207275935040320/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:14 sn02031601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-wstwvowpxvmdacxjbzejjbauuzggxxqo; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634214.62-246704654903631/stat; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634214.62-246704654903631/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:18 sn02031601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ekxizadihxnjtqdgvuqnbfhejqexatyd; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634218.09-220857996394524/file; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634218.09-220857996394524/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:22 sn02031601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ynfyhgtbsafcatxfziflcjvgfglqceqm; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634222.29-142877901632250/stat; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634222.29-142877901632250/" > /dev/null 2>&1
# /var/log/secure-20160814:Aug  8 14:30:25 sn02031601 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-jvqdeitpfoqygfiscwhchoiyqrvjzmex; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1470634225.73-41934094907741/file; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1470634225.73-41934094907741/" > /dev/null 2>&1grep: /var/log/audit: Is a directory
# grep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/lost+found: Is a directory
# grep: /var/log/munin: Is a directory
# grep: /var/log/munin-node: Is a directory
# grep: /var/log/ntpstats: Is a directory
# grep: /var/log/resources: Is a directory
# grep: /var/log/sa: Is a directory
# grep: /var/log/td-agent: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.113 | SUCCESS | rc=0 >>
# /var/log/secure-20160821:Aug 19 07:40:50 testvm006 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ndjndequqytpoochmikncetfxvwobdnv; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471560050.68-224498204323069/setup; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471560050.68-224498204323069/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 07:40:52 testvm006 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-yhlgvlnrsqdsxqgkymmmwzxcwxgjrtdf; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471560052.4-257225109773411/service; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471560052.4-257225109773411/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:46:50 testvm006 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-kqpfxqyguqcwfrnpzbhodlajnuxrwrzv; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471574810.14-236049713474262/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471574810.14-236049713474262/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:48:40 testvm006 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-cyvcpszqurqfmlwtokhwzdlaqbimaldr; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471574920.64-266945100370848/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471574920.64-266945100370848/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:52:16 testvm006 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-eoersiccmyukvybqxfsmtpunjvkuisdx; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575136.6-280219333655929/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575136.6-280219333655929/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:54:18 testvm006 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-yqsmpbqgunmqxoifpsytibijtohqmerc; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575258.57-482194479348/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575258.57-482194479348/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:55:33 testvm006 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-nmdbpopiiebitsoqsnoiynvqxaozvjxt; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575332.85-39828347783584/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575332.85-39828347783584/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:14 testvm006 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-bclkqfstphoncssydbrojxdedpyzusaj; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575374.22-62217686760742/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575374.22-62217686760742/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:52 testvm006 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-calsntpilowgbcedwitkpsfpynrfmrif; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575412.81-231395136628807/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575412.81-231395136628807/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:57:54 testvm006 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-noxjfxkwwaivacgghxsaxhlatqbdygpr; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575474.49-29079866977088/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575474.49-29079866977088/" > /dev/null 2>&1grep: /var/log/audit: Is a directory
# grep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/ntpstats: Is a directory
# grep: /var/log/zookeeper: Is a directory
#
# XXX.XXX.XXX.114 | SUCCESS | rc=0 >>
# /var/log/secure-20160821:Aug 19 07:40:51 testvm007 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-zwzuyksniodyanqamqcibojwoewumwpz; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471560051.42-152296838008321/setup; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471560051.42-152296838008321/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 07:40:53 testvm007 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-wzxtdbbqtjvpumavohiczoindzighika; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471560053.85-98008474168245/service; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471560053.85-98008474168245/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:46:50 testvm007 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-doixxfrehhjpqanniwurhnzqzbjddzkl; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471574810.47-249631179183976/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471574810.47-249631179183976/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:48:41 testvm007 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-jtquzobzbsruergqkkjohkpwnezcuuep; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471574921.15-111334120244005/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471574921.15-111334120244005/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:52:17 testvm007 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-ipdvbmnxarclnhnjfqpkvcadmohgkhvf; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575136.99-180826337003137/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575136.99-180826337003137/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:54:19 testvm007 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-mykbpixbdglberseblnaxaiksmaqbahd; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575258.95-166906622552172/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575258.95-166906622552172/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:55:33 testvm007 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-prylvlmyyejvwrtuegjoyairiucoghte; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575333.19-70884784549379/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575333.19-70884784549379/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:14 testvm007 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-fxxodcacfmxpmqfmrrjmzextmgglckap; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575374.38-224006965669598/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575374.38-224006965669598/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:56:53 testvm007 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-rupkpmoxlxkzkriqfbxkpqkjmkmkczwr; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575413.09-101296729527873/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575413.09-101296729527873/" > /dev/null 2>&1
# /var/log/secure-20160821:Aug 19 11:57:55 testvm007 sudo:  ansible : TTY=pts/0 ; PWD=/home/ansible ; USER=root ; COMMAND=/bin/sh -c echo BECOME-SUCCESS-nongxjjwhownmdcxldliscdweplflsmh; LANG=en_US.UTF-8 LC_ALL=en_US.UTF-8 LC_MESSAGES=en_US.UTF-8 /usr/bin/python /home/ansible/.ansible/tmp/ansible-tmp-1471575474.88-121014282551033/command; rm -rf "/home/ansible/.ansible/tmp/ansible-tmp-1471575474.88-121014282551033/" > /dev/null 2>&1grep: /var/log/audit: Is a directory
# grep: /var/log/cups: Is a directory
# grep: /var/log/hadoop: Is a directory
# grep: /var/log/hadoop-hdfs: Is a directory
# grep: /var/log/hadoop-yarn: Is a directory
# grep: /var/log/hbase: Is a directory
# grep: /var/log/ntpstats: Is a directory
# grep: /var/log/zookeeper: Is a directory

# %% [markdown]
# ### ログファイルが適切にrotateされていること - B
#
# 操作の記録がディスクを圧迫しないことを確認しておく。ログは短期的な(Ansibleによる)操作の記録として参照可能にしておくべきものという前提。長期的には、Notebookを証跡としてアーカイブしておくべき。

# %% [markdown]
# ## 共通の方法でホストの状況が確認できること - C
#
# Notebookによる操作実施時は、適当なチェックポイントごとに状況を記録することで、後戻りしたくなった時に戻れる(戻ったことが確認できる)ようにする。

# %% [markdown]
# ### OSのバージョン確認
#
# lsb_releaseを使う。

# %%
# !ansible -a 'lsb_release -a' all
# Out:
# XXX.XXX.XXX.193 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.194 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.229 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.197 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.195 | SUCCESS | rc=0 >>
# LSB Version:	:core-4.1-amd64:core-4.1-noarch:cxx-4.1-amd64:cxx-4.1-noarch:desktop-4.1-amd64:desktop-4.1-noarch:languages-4.1-amd64:languages-4.1-noarch:printing-4.1-amd64:printing-4.1-noarch
# Distributor ID:	CentOS
# Description:	CentOS Linux release 7.1.1503 (Core)
# Release:	7.1.1503
# Codename:	Core
#
# XXX.XXX.XXX.196 | SUCCESS | rc=0 >>
# LSB Version:	:core-4.1-amd64:core-4.1-noarch:cxx-4.1-amd64:cxx-4.1-noarch:desktop-4.1-amd64:desktop-4.1-noarch:languages-4.1-amd64:languages-4.1-noarch:printing-4.1-amd64:printing-4.1-noarch
# Distributor ID:	CentOS
# Description:	CentOS Linux release 7.1.1503 (Core)
# Release:	7.1.1503
# Codename:	Core
#
# XXX.XXX.XXX.198 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.199 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.70 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.8 (Final)
# Release:	6.8
# Codename:	Final
#
# XXX.XXX.XXX.72 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.8 (Final)
# Release:	6.8
# Codename:	Final
#
# XXX.XXX.XXX.71 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.8 (Final)
# Release:	6.8
# Codename:	Final
#
# XXX.XXX.XXX.106 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.8 (Final)
# Release:	6.8
# Codename:	Final
#
# XXX.XXX.XXX.200 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.230 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.228 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.226 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.225 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.236 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.234 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.232 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.231 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.233 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.227 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.235 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.7 (Final)
# Release:	6.7
# Codename:	Final
#
# XXX.XXX.XXX.73 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.8 (Final)
# Release:	6.8
# Codename:	Final
#
# XXX.XXX.XXX.112 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.8 (Final)
# Release:	6.8
# Codename:	Final
#
# XXX.XXX.XXX.113 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.8 (Final)
# Release:	6.8
# Codename:	Final
#
# XXX.XXX.XXX.114 | SUCCESS | rc=0 >>
# LSB Version:	:base-4.0-amd64:base-4.0-noarch:core-4.0-amd64:core-4.0-noarch:graphics-4.0-amd64:graphics-4.0-noarch:printing-4.0-amd64:printing-4.0-noarch
# Distributor ID:	CentOS
# Description:	CentOS release 6.8 (Final)
# Release:	6.8
# Codename:	Final

# %% [markdown]
# ### ファイル構成の確認
#
# treeコマンドを使う。

# %%
# !ansible -m shell -a 'tree /tmp/ansible_*' all
# Out:
# XXX.XXX.XXX.193 | SUCCESS | rc=0 >>
# /tmp/ansible_Rvm7DW
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.194 | SUCCESS | rc=0 >>
# /tmp/ansible_l1McIS
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.229 | SUCCESS | rc=0 >>
# /tmp/ansible_H1rnv9
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.197 | SUCCESS | rc=0 >>
# /tmp/ansible_IjeZ0q
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.195 | SUCCESS | rc=0 >>
# /tmp/ansible_DHgM_7
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.196 | SUCCESS | rc=0 >>
# /tmp/ansible_V2ZAVw
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.198 | SUCCESS | rc=0 >>
# /tmp/ansible_HBe9cz
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.199 | SUCCESS | rc=0 >>
# /tmp/ansible_Lc6scW
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.70 | SUCCESS | rc=0 >>
# /tmp/ansible_90SwuM
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.72 | SUCCESS | rc=0 >>
# /tmp/ansible_BrRRf6
# ├── ansible_modlib.zip
# └── ansible_module_copy.py
# /tmp/ansible_tGhjQX
# ├── ansible_modlib.zip
# └── ansible_module_command.py
# /tmp/ansible_wNB5O7
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 6 files
#
# XXX.XXX.XXX.106 | SUCCESS | rc=0 >>
# /tmp/ansible_V2Pyk9
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.71 | SUCCESS | rc=0 >>
# /tmp/ansible_VSRBrh
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.200 | SUCCESS | rc=0 >>
# /tmp/ansible_ruyFBU
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.230 | SUCCESS | rc=0 >>
# /tmp/ansible_uB0Ntz
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.228 | SUCCESS | rc=0 >>
# /tmp/ansible_yGlJff
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.226 | SUCCESS | rc=0 >>
# /tmp/ansible_Wn6StF
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.225 | SUCCESS | rc=0 >>
# /tmp/ansible_acy5EN
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.236 | SUCCESS | rc=0 >>
# /tmp/ansible_iSlt2l
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.234 | SUCCESS | rc=0 >>
# /tmp/ansible_sQlWb9
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.232 | SUCCESS | rc=0 >>
# /tmp/ansible_76aw26
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.231 | SUCCESS | rc=0 >>
# /tmp/ansible_1jKbXx
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.233 | SUCCESS | rc=0 >>
# /tmp/ansible_aGuJWJ
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.227 | SUCCESS | rc=0 >>
# /tmp/ansible_i9naOw
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.235 | SUCCESS | rc=0 >>
# /tmp/ansible__g7juI
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.73 | SUCCESS | rc=0 >>
# /tmp/ansible_SU9UCk
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.112 | SUCCESS | rc=0 >>
# /tmp/ansible_SKMDez
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.113 | SUCCESS | rc=0 >>
# /tmp/ansible_0ku9au
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files
#
# XXX.XXX.XXX.114 | SUCCESS | rc=0 >>
# /tmp/ansible_UKBpCQ
# ├── ansible_modlib.zip
# └── ansible_module_command.py
#
# 0 directories, 2 files

# %% [markdown]
# ## リソースの使用状況変化をモニタリングしていること - C
#
# Binding対象を操作した際に、予期せぬディスク使用量増加やサービス異常終了に気づけるよう、状況変化をモニタリングしていることが望ましい。
