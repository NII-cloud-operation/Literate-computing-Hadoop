# %% [markdown]
# # About: Hadoop - Set! Inventory
#
# ----
#
# このお手本では、ホスト表に記述されたマシンにNotebook(Ansible)からアクセスするため、
# Ansible用のInventoryファイルを更新する手順を説明しています。
#
# Hadoopクラスタを構成するホストのマスタは表形式で管理しています(例:  [hosts.csv](../edit/hosts.csv))
#
# このホスト表には、複数のクラスタに関して以下の情報が記述されます。
#
# - ホストが所属するクラスタ名
# - ホストの名前, マシンタイプ
# - ホストのIPアドレス
# - ホストのスペック
# - ホストに配置するサービス

# %% [markdown]
# ## *Operation Note*
#
# *This is a cell for your own recording.  ここに経緯を記述*

# %% [markdown]
# # 構築対象の指定
#
# Hadoopクラスタを構成するホスト表ファイル名を指定します。

# %%
# ホスト表ファイルのパス
hosts_csv = 'hosts.csv'

# %% [markdown]
# ## クラスタ情報の更新
#
# クラスタ情報を更新する。ここではテストクラスタに関する情報を追加することにします。(クラスタ名は `TestCluster` とします)
#
# まず、現在のホスト表ファイルをバックアップしておく。

# %%
import tempfile
work_dir = tempfile.mkdtemp()
work_dir
# Out:
# '/tmp/tmpC7TYKk'

# %%
# !cp hosts.csv {work_dir}/hosts-old.csv

# %% [markdown]
# [hosts.csv](../edit/hosts.csv) にVMの情報を追加し、各VMにロールを割り当てる。

# %%
# !diff -ur {work_dir}/hosts-old.csv hosts.csv
# Out:
# --- /tmp/tmpC7TYKk/hosts-old.csv	2016-08-26 11:27:12.642144914 +0900
# +++ hosts.csv	2016-08-26 11:27:38.622366625 +0900
# @@ -19,3 +19,10 @@
#  Cluster2,sn0202,sn02020801,XXX.XXX.XXX.10,XXX.XXX.XXX.229,16,65536,10,15,64512,,x,x,,x,,x,,x,,x,,,,,,,,,
#  Cluster2,sn0202,sn02021601,XXX.XXX.XXX.6,XXX.XXX.XXX.227,16,65536,10,15,64512,,,,,x,,x,,,,x,,,,,,,,,
#  Cluster2,sn0203,sn02030801,XXX.XXX.XXX.22,XXX.XXX.XXX.235,16,65536,10,15,64512,,,,,x,,x,,,,x,,,,,,,,,
# +TestCluster,vm,testvm001,,XXX.XXX.XXX.70,2,10240,-,-,-,x,x,x,x,,x,,,,x,,,,,,,,,,
# +TestCluster,vm,testvm002,,XXX.XXX.XXX.71,2,10240,-,-,-,,x,x,x,,x,,,,x,,,,,,,,,,
# +TestCluster,vm,testvm003,,XXX.XXX.XXX.72,2,10240,-,-,-,,x,x,,,,,x,x,,,x,x,x,x,x,x,,,
# +TestCluster,vm,testvm004,,XXX.XXX.XXX.73,2,10240,1,1,4096,,,,,x,,x,,,,x,,,,,,,,,
# +TestCluster,vm,testvm005,,XXX.XXX.XXX.112,2,10240,1,1,4096,,,,,x,,x,,,,x,,,,,,,,,
# +TestCluster,vm,testvm006,,XXX.XXX.XXX.113,2,10240,1,1,4096,,,,,x,,x,,,,x,,,,,,,,,
# +TestCluster,vm,testvm007,,XXX.XXX.XXX.114,2,10240,1,1,4096,,,,,x,,x,,,,x,,,,,,,,,

# %% [markdown]
# ## クラスタの情報の確認
#
# 最新のホスト一覧を表で確認します。

# %%
# %run scripts/loader.py

header, machines = read_machines(hosts_csv)

pd.DataFrame([get_row(header, m) for m in machines], columns=header)
# Out:
#         Cluster    Type        Name Internal IP     Service IP  VCPUs  \
# 0      Cluster1  cn0107  cn01070401  XXX.XXX.XXX.85  XXX.XXX.XXX.197     12
# 1      Cluster1  cn0107  cn01070402  XXX.XXX.XXX.86  XXX.XXX.XXX.198     12
# 2      Cluster1  cn0107  cn01070403  XXX.XXX.XXX.87  XXX.XXX.XXX.199     12
# 3      Cluster1  cn0107  cn01070404  XXX.XXX.XXX.88  XXX.XXX.XXX.200     12
# 4      Cluster1  cn0107  cn01070603  XXX.XXX.XXX.83  XXX.XXX.XXX.195     12
# 5      Cluster1  cn0107  cn01070604  XXX.XXX.XXX.84  XXX.XXX.XXX.196     12
# 6      Cluster1  sn0202  sn02020401  XXX.XXX.XXX.12  XXX.XXX.XXX.230     16
# 7      Cluster1  sn0202  sn02021201   XXX.XXX.XXX.8  XXX.XXX.XXX.228     16
# 8      Cluster1  sn0202  sn02022001   XXX.XXX.XXX.4  XXX.XXX.XXX.226     16
# 9      Cluster1  sn0202  sn02022401   XXX.XXX.XXX.2  XXX.XXX.XXX.225     16
# 10     Cluster1  sn0203  sn02030401  XXX.XXX.XXX.24  XXX.XXX.XXX.236     16
# 11     Cluster1  sn0203  sn02031201  XXX.XXX.XXX.20  XXX.XXX.XXX.234     16
# 12     Cluster1  sn0203  sn02032001  XXX.XXX.XXX.16  XXX.XXX.XXX.232     16
# 13     Cluster1  sn0203  sn02032401  XXX.XXX.XXX.14  XXX.XXX.XXX.231     16
# 14     Cluster1  sn0203  sn02031601  XXX.XXX.XXX.18  XXX.XXX.XXX.233     16
# 15     Cluster2  cn0107  cn01070601  XXX.XXX.XXX.81  XXX.XXX.XXX.193     12
# 16     Cluster2  cn0107  cn01070602  XXX.XXX.XXX.82  XXX.XXX.XXX.194     12
# 17     Cluster2  sn0202  sn02020801  XXX.XXX.XXX.10  XXX.XXX.XXX.229     16
# 18     Cluster2  sn0202  sn02021601   XXX.XXX.XXX.6  XXX.XXX.XXX.227     16
# 19     Cluster2  sn0203  sn02030801  XXX.XXX.XXX.22  XXX.XXX.XXX.235     16
# 20  TestCluster      vm   testvm001               XXX.XXX.XXX.70      2
# 21  TestCluster      vm   testvm002               XXX.XXX.XXX.71      2
# 22  TestCluster      vm   testvm003               XXX.XXX.XXX.72      2
# 23  TestCluster      vm   testvm004               XXX.XXX.XXX.73      2
# 24  TestCluster      vm   testvm005              XXX.XXX.XXX.112      2
# 25  TestCluster      vm   testvm006              XXX.XXX.XXX.113      2
# 26  TestCluster      vm   testvm007              XXX.XXX.XXX.114      2
#
#     Memory(MiB)  DFS Volumes  YARN VCPUs  YARN Total Memory(MB)  ...    \
# 0         98304          NaN         NaN                    NaN  ...
# 1         98304          NaN         NaN                    NaN  ...
# 2         98304          NaN         NaN                    NaN  ...
# 3         98304          NaN         NaN                    NaN  ...
# 4         98304          NaN         NaN                    NaN  ...
# 5         98304          NaN         NaN                    NaN  ...
# 6         65536         10.0        15.0                64512.0  ...
# 7         65536         10.0        15.0                64512.0  ...
# 8         65536         10.0        15.0                64512.0  ...
# 9         65536         10.0        15.0                64512.0  ...
# 10        65536         10.0        15.0                64512.0  ...
# 11        65536         10.0        15.0                64512.0  ...
# 12        65536         10.0        15.0                64512.0  ...
# 13        65536         10.0        15.0                64512.0  ...
# 14        65536         10.0        15.0                64512.0  ...
# 15        98304         10.0        11.0                97280.0  ...
# 16        98304         10.0        11.0                97280.0  ...
# 17        65536         10.0        15.0                64512.0  ...
# 18        65536         10.0        15.0                64512.0  ...
# 19        65536         10.0        15.0                64512.0  ...
# 20        10240          NaN         NaN                    NaN  ...
# 21        10240          NaN         NaN                    NaN  ...
# 22        10240          NaN         NaN                    NaN  ...
# 23        10240          1.0         1.0                 4096.0  ...
# 24        10240          1.0         1.0                 4096.0  ...
# 25        10240          1.0         1.0                 4096.0  ...
# 26        10240          1.0         1.0                 4096.0  ...
#
#    HBase RegionServer    Tez   Hive    Pig Client  Spark Spark HistoryServer  \
# 0               False  False  False  False  False  False               False
# 1               False  False  False  False  False  False               False
# 2               False  False  False  False  False  False               False
# 3               False   True   True   True   True   True                True
# 4               False  False  False  False  False  False               False
# 5               False  False  False  False  False  False               False
# 6                True  False  False  False  False  False               False
# 7                True  False  False  False  False  False               False
# 8                True  False  False  False  False  False               False
# 9                True  False  False  False  False  False               False
# 10               True  False  False  False  False  False               False
# 11               True  False  False  False  False  False               False
# 12               True  False  False  False  False  False               False
# 13               True  False  False  False  False  False               False
# 14               True  False  False  False  False  False               False
# 15              False  False  False  False  False  False               False
# 16              False   True   True   True   True   True                True
# 17               True  False  False  False  False  False               False
# 18               True  False  False  False  False  False               False
# 19               True  False  False  False  False  False               False
# 20              False  False  False  False  False  False               False
# 21              False  False  False  False  False  False               False
# 22              False   True   True   True   True   True                True
# 23               True  False  False  False  False  False               False
# 24               True  False  False  False  False  False               False
# 25               True  False  False  False  False  False               False
# 26               True  False  False  False  False  False               False
#
#    KDC Master KDC Slave Docker
# 0        True     False  False
# 1       False      True  False
# 2       False     False  False
# 3       False     False  False
# 4       False     False   True
# 5       False     False   True
# 6       False     False  False
# 7       False     False  False
# 8       False     False  False
# 9       False     False  False
# 10      False     False  False
# 11      False     False  False
# 12      False     False  False
# 13      False     False  False
# 14      False     False  False
# 15      False      True  False
# 16       True     False  False
# 17      False     False  False
# 18      False     False  False
# 19      False     False  False
# 20      False     False  False
# 21      False     False  False
# 22      False     False  False
# 23      False     False  False
# 24      False     False  False
# 25      False     False  False
# 26      False     False  False
#
# [27 rows x 30 columns]

# %% [markdown]
# # Ansible用ファイルの更新
#
#
# AnsibleにHadoop環境構築をおこなわせるため、以下の2つのファイルを更新します。
#
# - Inventory ... グループとホストの対応関係
# - group_vars ... 各Playbookに渡す変数
#
# このNotebookではInventoryのひな型のみを提供し、実際のマージは人手で行います。

# %% [markdown]
# ## Inventoryの更新
#
# Inventoryをアップデートします。先に確認したホスト表に基づいて、グループ定義を含むInventoryの内容を生成します。

# %%
# %run scripts/inventory-hadoop.py

with open('{work_dir}/hosts'.format(work_dir=work_dir), "w") as f:
    aliases = []
    for cluster in sorted(set(map(lambda m: m['Cluster'], machines))):
        aliases += write_hadoop_inventory(filter(lambda m: m['Cluster'] == cluster, machines), f)
    for group in sorted(set(map(lambda a: a[0], aliases))):
        f.write('''[{group}:children]
{targets}

'''.format(group=group, targets='\n'.join(map(lambda a: a[1], filter(lambda a: a[0] == group, aliases)))))

# !cat {work_dir}/hosts
# Out:
# [hadoop_all_cluster1:children]
# hadoop_master_cluster1
# hadoop_client_cluster1
# hadoop_slavenode_cluster1
# hadoop_hbase_cluster1
# hadoop_spark_cluster1
#
# [hadoop_swimlane_cluster1]
# XXX.XXX.XXX.200
#
# [hadoop_master_cluster1:children]
# hadoop_namenode_cluster1
# hadoop_journalnode_cluster1
# hadoop_zookeeperserver_cluster1
# hadoop_resourcemanager_cluster1
#
# [hadoop_hbase_cluster1:children]
# hadoop_hbase_master_cluster1
# hadoop_hbase_regionserver_cluster1
#
# [hadoop_spark_history_cluster1]
# XXX.XXX.XXX.200
#
# [hadoop_journalnode_cluster1]
# XXX.XXX.XXX.197
# XXX.XXX.XXX.198
# XXX.XXX.XXX.199
#
# [hadoop_client_cluster1]
# XXX.XXX.XXX.200
#
# [hadoop_zookeeperserver_cluster1]
# XXX.XXX.XXX.197 zookeeper_server_id=1
# XXX.XXX.XXX.198 zookeeper_server_id=2
# XXX.XXX.XXX.199 zookeeper_server_id=3
#
# [hadoop_namenode_cluster1:children]
# hadoop_namenode_primary_cluster1
# hadoop_namenode_backup_cluster1
#
# [kerberos_master_cluster1]
# XXX.XXX.XXX.197
#
# [hadoop_hive_cluster1]
# XXX.XXX.XXX.200
#
# [hadoop_hbase_regionserver_cluster1]
# XXX.XXX.XXX.230
# XXX.XXX.XXX.228
# XXX.XXX.XXX.226
# XXX.XXX.XXX.225
# XXX.XXX.XXX.236
# XXX.XXX.XXX.234
# XXX.XXX.XXX.232
# XXX.XXX.XXX.231
# XXX.XXX.XXX.233
#
# [hadoop_namenode_backup_cluster1]
# XXX.XXX.XXX.198
#
# [hadoop_resourcemanager_cluster1]
# XXX.XXX.XXX.197
# XXX.XXX.XXX.198
#
# [hadoop_mapreduce_historyserver_cluster1]
# XXX.XXX.XXX.200
#
# [hadoop_pig_cluster1]
# XXX.XXX.XXX.200
#
# [hadoop_hbase_master_cluster1]
# XXX.XXX.XXX.197
# XXX.XXX.XXX.198
#
# [hadoop_spark_cluster1]
# XXX.XXX.XXX.200
#
# [hadoop_slavenode_cluster1]
# XXX.XXX.XXX.230 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
# XXX.XXX.XXX.228 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
# XXX.XXX.XXX.226 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
# XXX.XXX.XXX.225 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
# XXX.XXX.XXX.236 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
# XXX.XXX.XXX.234 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
# XXX.XXX.XXX.232 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
# XXX.XXX.XXX.231 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
# XXX.XXX.XXX.233 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
#
# [hadoop_timelineservice_cluster1]
# XXX.XXX.XXX.199
#
# [hadoop_namenode_primary_cluster1]
# XXX.XXX.XXX.197
#
# [hadoop_tez_cluster1]
# XXX.XXX.XXX.200
#
# [hadoop_all_cluster2:children]
# hadoop_master_cluster2
# hadoop_client_cluster2
# hadoop_slavenode_cluster2
# hadoop_hbase_cluster2
# hadoop_spark_cluster2
#
# [hadoop_swimlane_cluster2]
# XXX.XXX.XXX.194
#
# [hadoop_master_cluster2:children]
# hadoop_namenode_cluster2
# hadoop_journalnode_cluster2
# hadoop_zookeeperserver_cluster2
# hadoop_resourcemanager_cluster2
#
# [hadoop_hbase_cluster2:children]
# hadoop_hbase_master_cluster2
# hadoop_hbase_regionserver_cluster2
#
# [hadoop_spark_history_cluster2]
# XXX.XXX.XXX.194
#
# [hadoop_journalnode_cluster2]
# XXX.XXX.XXX.193
# XXX.XXX.XXX.194
# XXX.XXX.XXX.229
#
# [hadoop_client_cluster2]
# XXX.XXX.XXX.194
#
# [hadoop_zookeeperserver_cluster2]
# XXX.XXX.XXX.193 zookeeper_server_id=1
# XXX.XXX.XXX.194 zookeeper_server_id=2
# XXX.XXX.XXX.229 zookeeper_server_id=3
#
# [hadoop_namenode_cluster2:children]
# hadoop_namenode_primary_cluster2
# hadoop_namenode_backup_cluster2
#
# [kerberos_master_cluster2]
# XXX.XXX.XXX.194
#
# [hadoop_hive_cluster2]
# XXX.XXX.XXX.194
#
# [hadoop_hbase_regionserver_cluster2]
# XXX.XXX.XXX.229
# XXX.XXX.XXX.227
# XXX.XXX.XXX.235
#
# [hadoop_namenode_backup_cluster2]
# XXX.XXX.XXX.194
#
# [hadoop_resourcemanager_cluster2]
# XXX.XXX.XXX.193
# XXX.XXX.XXX.194
#
# [hadoop_mapreduce_historyserver_cluster2]
# XXX.XXX.XXX.229
#
# [hadoop_pig_cluster2]
# XXX.XXX.XXX.194
#
# [hadoop_hbase_master_cluster2]
# XXX.XXX.XXX.193
# XXX.XXX.XXX.194
#
# [hadoop_spark_cluster2]
# XXX.XXX.XXX.194
#
# [hadoop_slavenode_cluster2]
# XXX.XXX.XXX.229 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
# XXX.XXX.XXX.227 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
# XXX.XXX.XXX.235 yarn_nodemanager_resource_cpu_vcores=15 yarn_nodemanager_resource_memory_mb=64512
#
# [hadoop_timelineservice_cluster2]
# XXX.XXX.XXX.193
#
# [hadoop_namenode_primary_cluster2]
# XXX.XXX.XXX.193
#
# [hadoop_tez_cluster2]
# XXX.XXX.XXX.194
#
# [hadoop_all_testcluster:children]
# hadoop_master_testcluster
# hadoop_client_testcluster
# hadoop_slavenode_testcluster
# hadoop_hbase_testcluster
# hadoop_spark_testcluster
#
# [hadoop_swimlane_testcluster]
# XXX.XXX.XXX.72
#
# [hadoop_master_testcluster:children]
# hadoop_namenode_testcluster
# hadoop_journalnode_testcluster
# hadoop_zookeeperserver_testcluster
# hadoop_resourcemanager_testcluster
#
# [hadoop_hbase_testcluster:children]
# hadoop_hbase_master_testcluster
# hadoop_hbase_regionserver_testcluster
#
# [hadoop_spark_history_testcluster]
# XXX.XXX.XXX.72
#
# [hadoop_journalnode_testcluster]
# XXX.XXX.XXX.70
# XXX.XXX.XXX.71
# XXX.XXX.XXX.72
#
# [hadoop_client_testcluster]
# XXX.XXX.XXX.72
#
# [hadoop_zookeeperserver_testcluster]
# XXX.XXX.XXX.70 zookeeper_server_id=1
# XXX.XXX.XXX.71 zookeeper_server_id=2
# XXX.XXX.XXX.72 zookeeper_server_id=3
#
# [hadoop_namenode_testcluster:children]
# hadoop_namenode_primary_testcluster
# hadoop_namenode_backup_testcluster
#
# [hadoop_hive_testcluster]
# XXX.XXX.XXX.72
#
# [hadoop_hbase_regionserver_testcluster]
# XXX.XXX.XXX.73
# XXX.XXX.XXX.112
# XXX.XXX.XXX.113
# XXX.XXX.XXX.114
#
# [hadoop_namenode_backup_testcluster]
# XXX.XXX.XXX.71
#
# [hadoop_resourcemanager_testcluster]
# XXX.XXX.XXX.70
# XXX.XXX.XXX.71
#
# [hadoop_mapreduce_historyserver_testcluster]
# XXX.XXX.XXX.72
#
# [hadoop_pig_testcluster]
# XXX.XXX.XXX.72
#
# [hadoop_hbase_master_testcluster]
# XXX.XXX.XXX.70
# XXX.XXX.XXX.71
#
# [hadoop_spark_testcluster]
# XXX.XXX.XXX.72
#
# [hadoop_slavenode_testcluster]
# XXX.XXX.XXX.73 yarn_nodemanager_resource_cpu_vcores=1 yarn_nodemanager_resource_memory_mb=4096
# XXX.XXX.XXX.112 yarn_nodemanager_resource_cpu_vcores=1 yarn_nodemanager_resource_memory_mb=4096
# XXX.XXX.XXX.113 yarn_nodemanager_resource_cpu_vcores=1 yarn_nodemanager_resource_memory_mb=4096
# XXX.XXX.XXX.114 yarn_nodemanager_resource_cpu_vcores=1 yarn_nodemanager_resource_memory_mb=4096
#
# [hadoop_timelineservice_testcluster]
# XXX.XXX.XXX.72
#
# [hadoop_namenode_primary_testcluster]
# XXX.XXX.XXX.70
#
# [hadoop_tez_testcluster]
# XXX.XXX.XXX.72
#
# [hadoop_all:children]
# hadoop_all_cluster1
# hadoop_all_cluster2
# hadoop_all_testcluster
#
# [hadoop_client:children]
# hadoop_client_cluster1
# hadoop_client_cluster2
# hadoop_client_testcluster
#
# [hadoop_hbase:children]
# hadoop_hbase_cluster1
# hadoop_hbase_cluster2
# hadoop_hbase_testcluster
#
# [hadoop_hbase_master:children]
# hadoop_hbase_master_cluster1
# hadoop_hbase_master_cluster2
# hadoop_hbase_master_testcluster
#
# [hadoop_hbase_regionserver:children]
# hadoop_hbase_regionserver_cluster1
# hadoop_hbase_regionserver_cluster2
# hadoop_hbase_regionserver_testcluster
#
# [hadoop_hive:children]
# hadoop_hive_cluster1
# hadoop_hive_cluster2
# hadoop_hive_testcluster
#
# [hadoop_journalnode:children]
# hadoop_journalnode_cluster1
# hadoop_journalnode_cluster2
# hadoop_journalnode_testcluster
#
# [hadoop_mapreduce_historyserver:children]
# hadoop_mapreduce_historyserver_cluster1
# hadoop_mapreduce_historyserver_cluster2
# hadoop_mapreduce_historyserver_testcluster
#
# [hadoop_master:children]
# hadoop_master_cluster1
# hadoop_master_cluster2
# hadoop_master_testcluster
#
# [hadoop_namenode:children]
# hadoop_namenode_cluster1
# hadoop_namenode_cluster2
# hadoop_namenode_testcluster
#
# [hadoop_namenode_backup:children]
# hadoop_namenode_backup_cluster1
# hadoop_namenode_backup_cluster2
# hadoop_namenode_backup_testcluster
#
# [hadoop_namenode_primary:children]
# hadoop_namenode_primary_cluster1
# hadoop_namenode_primary_cluster2
# hadoop_namenode_primary_testcluster
#
# [hadoop_pig:children]
# hadoop_pig_cluster1
# hadoop_pig_cluster2
# hadoop_pig_testcluster
#
# [hadoop_resourcemanager:children]
# hadoop_resourcemanager_cluster1
# hadoop_resourcemanager_cluster2
# hadoop_resourcemanager_testcluster
#
# [hadoop_slavenode:children]
# hadoop_slavenode_cluster1
# hadoop_slavenode_cluster2
# hadoop_slavenode_testcluster
#
# [hadoop_spark:children]
# hadoop_spark_cluster1
# hadoop_spark_cluster2
# hadoop_spark_testcluster
#
# [hadoop_spark_history:children]
# hadoop_spark_history_cluster1
# hadoop_spark_history_cluster2
# hadoop_spark_history_testcluster
#
# [hadoop_swimlane:children]
# hadoop_swimlane_cluster1
# hadoop_swimlane_cluster2
# hadoop_swimlane_testcluster
#
# [hadoop_tez:children]
# hadoop_tez_cluster1
# hadoop_tez_cluster2
# hadoop_tez_testcluster
#
# [hadoop_timelineservice:children]
# hadoop_timelineservice_cluster1
# hadoop_timelineservice_cluster2
# hadoop_timelineservice_testcluster
#
# [hadoop_zookeeperserver:children]
# hadoop_zookeeperserver_cluster1
# hadoop_zookeeperserver_cluster2
# hadoop_zookeeperserver_testcluster
#
# [kerberos_master:children]
# kerberos_master_cluster1
# kerberos_master_cluster2

# %% [markdown]
# 上の出力結果を、Inventoryに反映します。すでにInventoryには別のマシンに関する情報もある可能性を考慮し、手作業でのマージとします。

# %%
# !cp inventory {work_dir}/inventory-old

# %% [markdown]
# [Inventory](../edit/inventory) を修正する。

# %%
# !diff -ur {work_dir}/inventory-old inventory
# Out:
# --- /tmp/tmpC7TYKk/inventory-old	2016-08-26 11:28:11.990651381 +0900
# +++ inventory	2016-08-26 11:28:47.486954290 +0900
# @@ -196,89 +196,194 @@
#  [hadoop_tez_cluster2]
#  XXX.XXX.XXX.194
#
# +[hadoop_all_testcluster:children]
# +hadoop_master_testcluster
# +hadoop_client_testcluster
# +hadoop_slavenode_testcluster
# +hadoop_hbase_testcluster
# +hadoop_spark_testcluster
# +
# +[hadoop_swimlane_testcluster]
# +XXX.XXX.XXX.72
# +
# +[hadoop_master_testcluster:children]
# +hadoop_namenode_testcluster
# +hadoop_journalnode_testcluster
# +hadoop_zookeeperserver_testcluster
# +hadoop_resourcemanager_testcluster
# +
# +[hadoop_hbase_testcluster:children]
# +hadoop_hbase_master_testcluster
# +hadoop_hbase_regionserver_testcluster
# +
# +[hadoop_spark_history_testcluster]
# +XXX.XXX.XXX.72
# +
# +[hadoop_journalnode_testcluster]
# +XXX.XXX.XXX.70
# +XXX.XXX.XXX.71
# +XXX.XXX.XXX.72
# +
# +[hadoop_client_testcluster]
# +XXX.XXX.XXX.72
# +
# +[hadoop_zookeeperserver_testcluster]
# +XXX.XXX.XXX.70 zookeeper_server_id=1
# +XXX.XXX.XXX.71 zookeeper_server_id=2
# +XXX.XXX.XXX.72 zookeeper_server_id=3
# +
# +[hadoop_namenode_testcluster:children]
# +hadoop_namenode_primary_testcluster
# +hadoop_namenode_backup_testcluster
# +
# +[hadoop_hive_testcluster]
# +XXX.XXX.XXX.72
# +
# +[hadoop_hbase_regionserver_testcluster]
# +XXX.XXX.XXX.73
# +XXX.XXX.XXX.112
# +XXX.XXX.XXX.113
# +XXX.XXX.XXX.114
# +
# +[hadoop_namenode_backup_testcluster]
# +XXX.XXX.XXX.71
# +
# +[hadoop_resourcemanager_testcluster]
# +XXX.XXX.XXX.70
# +XXX.XXX.XXX.71
# +
# +[hadoop_mapreduce_historyserver_testcluster]
# +XXX.XXX.XXX.72
# +
# +[hadoop_pig_testcluster]
# +XXX.XXX.XXX.72
# +
# +[hadoop_hbase_master_testcluster]
# +XXX.XXX.XXX.70
# +XXX.XXX.XXX.71
# +
# +[hadoop_spark_testcluster]
# +XXX.XXX.XXX.72
# +
# +[hadoop_slavenode_testcluster]
# +XXX.XXX.XXX.73 yarn_nodemanager_resource_cpu_vcores=1 yarn_nodemanager_resource_memory_mb=4096
# +XXX.XXX.XXX.112 yarn_nodemanager_resource_cpu_vcores=1 yarn_nodemanager_resource_memory_mb=4096
# +XXX.XXX.XXX.113 yarn_nodemanager_resource_cpu_vcores=1 yarn_nodemanager_resource_memory_mb=4096
# +XXX.XXX.XXX.114 yarn_nodemanager_resource_cpu_vcores=1 yarn_nodemanager_resource_memory_mb=4096
# +
# +[hadoop_timelineservice_testcluster]
# +XXX.XXX.XXX.72
# +
# +[hadoop_namenode_primary_testcluster]
# +XXX.XXX.XXX.70
# +
# +[hadoop_tez_testcluster]
# +XXX.XXX.XXX.72
# +
#  [hadoop_all:children]
#  hadoop_all_cluster1
#  hadoop_all_cluster2
# +hadoop_all_testcluster
#
#  [hadoop_client:children]
#  hadoop_client_cluster1
#  hadoop_client_cluster2
# +hadoop_client_testcluster
#
#  [hadoop_hbase:children]
#  hadoop_hbase_cluster1
#  hadoop_hbase_cluster2
# +hadoop_hbase_testcluster
#
#  [hadoop_hbase_master:children]
#  hadoop_hbase_master_cluster1
#  hadoop_hbase_master_cluster2
# +hadoop_hbase_master_testcluster
#
#  [hadoop_hbase_regionserver:children]
#  hadoop_hbase_regionserver_cluster1
#  hadoop_hbase_regionserver_cluster2
# +hadoop_hbase_regionserver_testcluster
#
#  [hadoop_hive:children]
#  hadoop_hive_cluster1
#  hadoop_hive_cluster2
# +hadoop_hive_testcluster
#
#  [hadoop_journalnode:children]
#  hadoop_journalnode_cluster1
#  hadoop_journalnode_cluster2
# +hadoop_journalnode_testcluster
#
#  [hadoop_mapreduce_historyserver:children]
#  hadoop_mapreduce_historyserver_cluster1
#  hadoop_mapreduce_historyserver_cluster2
# +hadoop_mapreduce_historyserver_testcluster
#
#  [hadoop_master:children]
#  hadoop_master_cluster1
#  hadoop_master_cluster2
# +hadoop_master_testcluster
#
#  [hadoop_namenode:children]
#  hadoop_namenode_cluster1
#  hadoop_namenode_cluster2
# +hadoop_namenode_testcluster
#
#  [hadoop_namenode_backup:children]
#  hadoop_namenode_backup_cluster1
#  hadoop_namenode_backup_cluster2
# +hadoop_namenode_backup_testcluster
#
#  [hadoop_namenode_primary:children]
#  hadoop_namenode_primary_cluster1
#  hadoop_namenode_primary_cluster2
# +hadoop_namenode_primary_testcluster
#
#  [hadoop_pig:children]
#  hadoop_pig_cluster1
#  hadoop_pig_cluster2
# +hadoop_pig_testcluster
#
#  [hadoop_resourcemanager:children]
#  hadoop_resourcemanager_cluster1
#  hadoop_resourcemanager_cluster2
# +hadoop_resourcemanager_testcluster
#
#  [hadoop_slavenode:children]
#  hadoop_slavenode_cluster1
#  hadoop_slavenode_cluster2
# +hadoop_slavenode_testcluster
#
#  [hadoop_spark:children]
#  hadoop_spark_cluster1
#  hadoop_spark_cluster2
# +hadoop_spark_testcluster
#
#  [hadoop_spark_history:children]
#  hadoop_spark_history_cluster1
#  hadoop_spark_history_cluster2
# +hadoop_spark_history_testcluster
#
#  [hadoop_swimlane:children]
#  hadoop_swimlane_cluster1
#  hadoop_swimlane_cluster2
# +hadoop_swimlane_testcluster
#
#  [hadoop_tez:children]
#  hadoop_tez_cluster1
#  hadoop_tez_cluster2
# +hadoop_tez_testcluster
#
#  [hadoop_timelineservice:children]
#  hadoop_timelineservice_cluster1
#  hadoop_timelineservice_cluster2
# +hadoop_timelineservice_testcluster
#
#  [hadoop_zookeeperserver:children]
#  hadoop_zookeeperserver_cluster1
#  hadoop_zookeeperserver_cluster2
# +hadoop_zookeeperserver_testcluster
#
#  [kerberos_master:children]
#  kerberos_master_cluster1

# %% [markdown]
# hadoop_all グループでHadoopクラスタに所属するサーバすべてに疎通することを確認する。

# %%
# !ansible -m ping hadoop_all
# Out:
# XXX.XXX.XXX.197 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.198 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.199 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.200 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.230 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.228 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.226 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.225 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.236 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.234 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.232 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.231 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.193 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.233 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.194 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.229 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.227 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.235 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.70 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.72 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.71 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.73 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.112 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.113 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }
# XXX.XXX.XXX.114 | SUCCESS => {
#     "changed": false,
#     "ping": "pong"
# }

# %% [markdown]
# ## グループ変数定義(hadoop\_all\_{cluster})の生成

# %%
archive_url = 'http://xxx.xxx.nii.ac.jp:YYYY/v1/AUTH_XXXXXXXXXXXXXXXXXXXXXXXX/HDP-2.x/archive'

# %%
# !mkdir -p {work_dir}/group_vars

for cluster in sorted(set(map(lambda m: m['Cluster'], machines))):
    with open("{work_dir}/group_vars/hadoop_all_{cluster}".format(work_dir=work_dir, cluster=cluster.lower()), "w") as f:
        write_hadoop_group_vars(filter(lambda m: m['Cluster'] == cluster, machines), f, archive_url)
    
# !cat {work_dir}/group_vars/hadoop_all_testcluster
# Out:
# # HDP repository
# hdp_version: 'XXX.XXX.XXX.0-258'
# base_hdp_hdp_baseurl: 'http://public-repo-1.hortonworks.com/HDP/centos6/2.x/updates/XXX.XXX.XXX.0'
# base_hdp_hdp_gpgcheck: '1'
# base_hdp_hdp_gpgkeyurl: 'http://public-repo-1.hortonworks.com/HDP/centos6/2.x/updates/XXX.XXX.XXX.0/RPM-GPG-KEY/RPM-GPG-KEY-Jenkins'
# base_hdp_util_baseurl: 'http://public-repo-1.hortonworks.com/HDP-UTILS-XXX.XXX.XXX.20/repos/centos6'
# base_hdp_util_gpgcheck: '1'
# base_hdp_util_gpgkeyurl: 'http://public-repo-1.hortonworks.com/HDP/centos6/2.x/updates/XXX.XXX.XXX.0/RPM-GPG-KEY/RPM-GPG-KEY-Jenkins'
#
# # define servers
# gmond: 'XXX.XXX.XXX.70'
# ganglia_cluster: 'TestCluster'
# ganglia_master: 'XXX.XXX.XXX.70'
#
# zookeeper_servers:
#   - 'testvm001'
#   - 'testvm002'
#   - 'testvm003'
#
# hadoop_namenode_servers:
#   - 'testvm001'
#   - 'testvm002'
#
# hadoop_slavenode_servers:
#   - 'testvm004'
#   - 'testvm005'
#   - 'testvm006'
#   - 'testvm007'
#
# hadoop_journalnode_servers:
#   - 'testvm001'
#   - 'testvm002'
#   - 'testvm003'
#
# hadoop_resourcemanager_servers:
#   - 'testvm001'
#   - 'testvm002'
#
# hadoop_timelineservice_server: 'testvm003'
#
# mapreduce_historyserver_address: 'testvm003'
#
# # cgroups
# cgroups_scripts_dir: '/var/local/cgroups'
#
# # Java
# jdk7_downloadurl: 'http://xxx.xxx.nii.ac.jp:YYYY/v1/AUTH_XXXXXXXXXXXXXXXXXXXXXXXX/HDP-2.x/archive'
# jdk8_downloadurl: 'http://xxx.xxx.nii.ac.jp:YYYY/v1/AUTH_XXXXXXXXXXXXXXXXXXXXXXXX/HDP-2.x/archive'
# # Swimlane
# swimlane_tez_version: '0.8.4'
#
# # HDFS
# dfs_namenode_name_dirs:
#   - '/hadoop/data/dfs/namedir'
#
# dfs_datanode_data_dirs:
#   - '/hadoop/data01/dfs/datadir'
# dfs_replication: '3'
# dfs_journalnode_edits_dir: '/hadoop/data/jn'
#
# # HBase
# hbase_root_dir: '/hbase'
#
# # Hive
# hive_metastore_dir: '/hadoop/data/hive/metastore'
#
# # Zookeeper
# zookeeper_data_dir: '/hadoop/zookeeper'
#
# # YARN
# yarn_nodemanager_delete_debug_delay_sec: '3600'
# mapreduce_am_resource_mb: 4096
# mapreduce_am_command_opts: "-Xmx3840m"
# mapreduce_map_memory_mb: 4096
# mapreduce_map_java_opts: "-Xmx3840m"
# mapreduce_reduce_memory_mb: 4096
# mapreduce_reduce_java_opts: "-Xmx3840m"
#
# # Spark
# spark_download_url: 'http://xxx.xxx.nii.ac.jp:YYYY/v1/AUTH_XXXXXXXXXXXXXXXXXXXXXXXX/HDP-2.x/archive'
# spark_history_server_host: 'testvm003'

# %% [markdown]
# このファイルをInventoryと同じディレクトリ配下の[group_vars](../tree/group_vars/)ディレクトリに配置する。

# %%
# !cp {work_dir}/group_vars/hadoop_all_testcluster group_vars/

# %%
# !ls -la group_vars/
# Out:
# total 36
# drwxr-xr-x  3 root root  4096 Aug 26 11:30 .
# drwxr-xr-x 19 root root 12288 Aug 26 11:30 ..
# -rw-r--r--  1 root root    71 Jul 29 12:03 docker_host
# -rw-r--r--  1 root root     0 Aug 22 11:35 .gitkeep
# -rw-r--r--  1 root root  2985 Aug  8 14:25 hadoop_all_cluster1
# -rw-r--r--  1 root root  2883 Jul 28 14:01 hadoop_all_cluster2
# -rw-r--r--  1 root root  2179 Aug 26 11:30 hadoop_all_testcluster
# drwxr-xr-x  2 root root  4096 Jul 29 12:02 .ipynb_checkpoints

# %% [markdown]
# # 動作確認
#
# 変数が読み込まれていることを確認する。

# %%
# %%writefile {work_dir}/test.yml
# - hosts: hadoop_all
#   tasks:
#     - debug: msg={{ hadoop_timelineservice_server }}
# Out:
# Writing /tmp/tmpC7TYKk/test.yml

# %%
# !ansible-playbook {work_dir}/test.yml
# Out:
# PLAY [hadoop_all] **************************************************************
#
# TASK [setup] *******************************************************************
# ok: [XXX.XXX.XXX.197]
# ok: [XXX.XXX.XXX.198]
# ok: [XXX.XXX.XXX.199]
# ok: [XXX.XXX.XXX.200]
# ok: [XXX.XXX.XXX.230]
# ok: [XXX.XXX.XXX.228]
# ok: [XXX.XXX.XXX.226]
# ok: [XXX.XXX.XXX.225]
# ok: [XXX.XXX.XXX.236]
# ok: [XXX.XXX.XXX.234]
# ok: [XXX.XXX.XXX.232]
# ok: [XXX.XXX.XXX.231]
# ok: [XXX.XXX.XXX.193]
# ok: [XXX.XXX.XXX.194]
# ok: [XXX.XXX.XXX.233]
# ok: [XXX.XXX.XXX.229]
# ok: [XXX.XXX.XXX.227]
# ok: [XXX.XXX.XXX.235]
# ok: [XXX.XXX.XXX.70]
# ok: [XXX.XXX.XXX.71]
# ok: [XXX.XXX.XXX.73]
# ok: [XXX.XXX.XXX.72]
# ok: [XXX.XXX.XXX.112]
# ok: [XXX.XXX.XXX.114]
# ok: [XXX.XXX.XXX.113]
#
# TASK [debug] *******************************************************************
# ok: [XXX.XXX.XXX.197] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.198] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.199] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.200] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.230] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.228] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.226] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.225] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.236] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.234] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.232] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.231] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.233] => {
#     "msg": "cn01070403"
# }
# ok: [XXX.XXX.XXX.193] => {
#     "msg": "cn01070601"
# }
# ok: [XXX.XXX.XXX.194] => {
#     "msg": "cn01070601"
# }
# ok: [XXX.XXX.XXX.229] => {
#     "msg": "cn01070601"
# }
# ok: [XXX.XXX.XXX.227] => {
#     "msg": "cn01070601"
# }
# ok: [XXX.XXX.XXX.235] => {
#     "msg": "cn01070601"
# }
# ok: [XXX.XXX.XXX.70] => {
#     "msg": "testvm003"
# }
# ok: [XXX.XXX.XXX.71] => {
#     "msg": "testvm003"
# }
# ok: [XXX.XXX.XXX.72] => {
#     "msg": "testvm003"
# }
# ok: [XXX.XXX.XXX.73] => {
#     "msg": "testvm003"
# }
# ok: [XXX.XXX.XXX.112] => {
#     "msg": "testvm003"
# }
# ok: [XXX.XXX.XXX.113] => {
#     "msg": "testvm003"
# }
# ok: [XXX.XXX.XXX.114] => {
#     "msg": "testvm003"
# }
#
# PLAY RECAP *********************************************************************
# XXX.XXX.XXX.193              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.194              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.197              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.198              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.199              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.200              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.225              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.226              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.227              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.228              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.229              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.230              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.231              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.232              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.233              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.234              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.235              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.236              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.112              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.113              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.114              : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.70               : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.71               : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.72               : ok=2    changed=0    unreachable=0    failed=0
# XXX.XXX.XXX.73               : ok=2    changed=0    unreachable=0    failed=0

# %% [markdown]
# OK。

# %% [markdown]
# # 後始末
#
# 一時ディレクトリを削除する。

# %%
# !rm -fr {work_dir}
